# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(f'The dataset contains {df.shape[0]} rows, and {df.shape[1]} columns')
# Out:
# The dataset contains 768 rows, and 9 columns

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
for i in df.columns:
    print(i,len(df[i].unique()))
# Out:
# Pregnancies 17
# Glucose 136
# BloodPressure 47
# SkinThickness 51
# Insulin 186
# BMI 248
# DiabetesPedigreeFunction 517
# Age 52
# Outcome 2

# %%
for i in df.columns:
    if len(df[i].unique())<100:
        print(f'{i} has {len(df[i].unique())} unique values, These are: {df[i].unique()}')
# Out:
# Pregnancies has 17 unique values, These are: [ 6  1  8  0  5  3 10  2  4  7  9 11 13 15 17 12 14]
# BloodPressure has 47 unique values, These are: [ 72  66  64  40  74  50   0  70  96  92  80  60  84  30  88  90  94  76
#   82  75  58  78  68 110  56  62  85  86  48  44  65 108  55 122  54  52
#   98 104  95  46 102 100  61  24  38 106 114]
# SkinThickness has 51 unique values, These are: [35 29  0 23 32 45 19 47 38 30 41 33 26 15 36 11 31 37 42 25 18 24 39 27
#  21 34 10 60 13 20 22 28 54 40 51 56 14 17 50 44 12 46 16  7 52 43 48  8
#  49 63 99]
# Age has 52 unique values, These are: [50 31 32 21 33 30 26 29 53 54 34 57 59 51 27 41 43 22 38 60 28 45 35 46
#  56 37 48 40 25 24 58 42 44 39 36 23 61 69 62 55 65 47 52 66 49 63 67 72
#  81 64 70 68]
# Outcome has 2 unique values, These are: [1 0]

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
sns.set(rc={'figure.figsize':(9,7)})
sns.barplot(data= df, x='Pregnancies',y='Outcome')
plt.title('Pregnancies v/s Outcome\n')
plt.show()

# %%
sns.set(rc={'figure.figsize':(9,7)})
sns.scatterplot(data= df, x='Glucose',y='BloodPressure', hue='Outcome')
plt.title('Pregnancies v/s Outcome\n')
plt.show()

# %%
sns.set(rc={'figure.figsize':(9,7)})
sns.histplot(data= df, x='BMI',hue='Outcome')
plt.title('Pregnancies v/s Outcome\n')
plt.show()
